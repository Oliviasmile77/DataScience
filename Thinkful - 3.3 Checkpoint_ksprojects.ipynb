# %%
import pandas as pd
ksprojects = pd.read_csv(r'C:\Users\ojiang1\Desktop\Data Science\ksprojects.csv')

# %%
ksprojects.shape
#1. 65418 rows
# Out:
# (65418, 13)

# %%
#2.  names and data types of the columns
ksprojects.columns
# Out:
# Index(['id', 'name', 'category', 'main_category', 'deadline', 'goal',
#        'launched', 'state', 'backers', 'country', 'usd_pledged', 'currency',
#        'pledged'],
#       dtype='object')

# %%
#3. after drop null, the columns changed from 13 to 12, so one of the columns contain null values
ksprojects.info()
ksprojects_dropnull = ksprojects.dropna(axis=1)
ksprojects_dropnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65418 entries, 0 to 65417
# Data columns (total 13 columns):
# id               65418 non-null int64
# name             65418 non-null object
# category         65418 non-null object
# main_category    65418 non-null object
# deadline         65418 non-null object
# goal             65418 non-null float64
# launched         65418 non-null object
# state            65418 non-null object
# backers          65418 non-null int64
# country          65418 non-null object
# usd_pledged      64673 non-null float64
# currency         65418 non-null object
# pledged          65418 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 6.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65418 entries, 0 to 65417
# Data columns (total 12 columns):
# id               65418 non-null int64
# name             65418 non-null object
# category         65418 non-null object
# main_category    65418 non-null object
# ...

# %% [markdown]
# 4. Find all successful documentary projects and sort them by the amount pledged. Print the top 10 highest pledges.

# %%
state=ksprojects.loc[(ksprojects['state']=='successful')]
state_sorted = state.sort_values(by=['usd_pledged'], ascending=False)
state_sorted.head(10)
# Out:
#                id                                               name  \
# 12253  1033978702             OUYA: A New Kind of Video Game Console
# 26917  1152735261     Pono Music - Where Your Soul Rediscovers Music
# 45290  1074800880                  Bloodstained: Ritual of the Night
# 46419  1045500705                            Zombicide: Black Plague
# 59897   132311747                                   Massive Darkness
# 27604  1265992004     The Micro: The First Truly Consumer 3D Printer
# 45456  1194278206         Yooka-Laylee - A 3D Platformer Rare-vival!
# 22674   127494612  Reaper Miniatures Bones II: The Return Of Mr B...
# 47232  1194924825  Reaper Miniatures Bones 3: The Search for Mr. ...
# 57199  1241205786  OSSIC X: The first 3D audio headphones calibra...
#
#               category main_category             deadline      goal  \
# 12253  Gaming Hardware         Games  2012-08-09 07:00:00  950000.0
# 26917            Sound    Technology  2014-04-15 19:30:42  800000.0
# ...

# %% [markdown]
# 5. Create a new column named average_per_backer and set its value to the total amount pledged / number of backers. What happened to the rows with 0 backers? How can this be dealt with?

# %%
ksprojects_backer = ksprojects[ksprojects.backers>0]
ksprojects_avgbacker = ksprojects_baker.assign(average_per_backer=ksprojects_baker.usd_pledged/ksprojects_baker.backers)
ksprojects_avgbacker.head(5)
# Out:
#            id                                               name  \
# 0  1147015301  "All We Had" Gets Into Cannes -- $10 or More G...
# 1  1100844465                                       daily digest
# 2  1316334968                             Drive A Faster Car 2.0
# 3  1304906577         Accidental to Edinburgh - PHASE 1: AIRFARE
# 4  1099226462          Logical Guess Pictures' 2nd Horror Movie!
#
#        category main_category             deadline    goal  \
# 0   Documentary  Film & Video  2009-05-20 21:50:00   300.0
# 1   Documentary  Film & Video  2009-06-01 02:20:00   700.0
# 2    Nonfiction    Publishing  2009-06-04 06:00:00  1000.0
# 3       Theater       Theater  2009-06-05 05:59:00  6000.0
# 4  Film & Video  Film & Video  2009-06-06 00:45:00   500.0
#
#               launched       state  backers country  usd_pledged currency  \
# 0  2009-04-30 22:10:30      failed        4      US        40.00      USD
# ...

# %% [markdown]
# 6. Drop all rows with 0 backers then repeat the previous exercise.

# %%
ksprojects_backer = ksprojects.dropna()
ksprojects_avgbacker = ksprojects_baker.assign(average_per_backer=ksprojects_baker.usd_pledged/ksprojects_baker.backers)
ksprojects_avgbacker.head(3)
# Out:
#            id                                               name     category  \
# 0  1147015301  "All We Had" Gets Into Cannes -- $10 or More G...  Documentary
# 1  1100844465                                       daily digest  Documentary
# 2  1316334968                             Drive A Faster Car 2.0   Nonfiction
#
#   main_category             deadline    goal             launched       state  \
# 0  Film & Video  2009-05-20 21:50:00   300.0  2009-04-30 22:10:30      failed
# 1  Film & Video  2009-06-01 02:20:00   700.0  2009-05-04 21:14:28  successful
# 2    Publishing  2009-06-04 06:00:00  1000.0  2009-05-04 22:51:31  successful
#
#    backers country  usd_pledged currency  pledged  average_per_backer
# 0        4      US         40.0      USD     40.0            10.00000
# 1       14      US        700.0      USD    700.0            50.00000
# 2       32      US       1367.0      USD   1367.0            42.71875

# %% [markdown]
# 7. Create a crosstab to get a count of records for each combination of state and category.

# %%
pd.crosstab(ksprojects_nodup['state'], ksprojects_nodup['category'])
# Out:
# category    3D Printing  Academic  Accessories  Action  Animals  Animation  \
# state
# canceled             17        21           48      14        2         41
# failed               59        86          238      79       31        245
# live                  3         3           16       1        0          8
# successful           43        43          121      16       11        134
# suspended             2         4            2       0        1          1
# undefined             1         0            1       0        0          0
#
# category    Anthologies  Apparel  Apps  Architecture  ...    Wearables  \
# state                                                 ...
# canceled              4      127   166            10  ...           25
# failed               34      684   784            86  ...           71
# live                  6       37    28             4  ...            7
# successful           83      211    55            26  ...           57
# ...
